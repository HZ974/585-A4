# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'cs585/CS585_spring_A4'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['README', 'job_script', 'scc_quick_setup_guide.txt', 'README.md', '.gitignore', 'image_vis.png', 'label_vis.png', '.idea', '.git', '__pycache__', 'CamVid', '.conda', 'vis', 'test_pred.npy', 'fcn_dataset.py', 'Jupyter_testing.ipynb', 'fcn_model.py', 'train.py', 'train.ipynb']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()



pytorch101_path = os.path.join(GOOGLE_DRIVE_PATH, 'train.py')
pytorch101_edit_time = time.ctime(os.path.getmtime(pytorch101_path))
print('train.py last edited on %s' % pytorch101_edit_time)

import train
train.main()
# Out:
# train.py last edited on Fri Apr  5 18:34:23 2024
# Epoch [1/80], Step [10/24], Loss: 12.4636
# Epoch [1/80], Step [20/24], Loss: 5.1409
# Pixel accuracy: 0.2061, Mean IoU: 0.0152, Frequency weighted IoU: 0.1149, Loss: 2.3032
# Epoch [2/80], Step [10/24], Loss: 2.1940
# Epoch [2/80], Step [20/24], Loss: 1.6908
# Pixel accuracy: 0.5563, Mean IoU: 0.0529, Frequency weighted IoU: 0.3853, Loss: 1.5741
# Epoch [3/80], Step [10/24], Loss: 1.4897
# Epoch [3/80], Step [20/24], Loss: 1.3547
# Pixel accuracy: 0.6063, Mean IoU: 0.0632, Frequency weighted IoU: 0.4350, Loss: 1.3870
# Epoch [4/80], Step [10/24], Loss: 1.2261
# Epoch [4/80], Step [20/24], Loss: 1.2268
# Pixel accuracy: 0.6419, Mean IoU: 0.0759, Frequency weighted IoU: 0.4727, Loss: 1.2249
# Epoch [5/80], Step [10/24], Loss: 1.1509
# Epoch [5/80], Step [20/24], Loss: 1.0571
# Pixel accuracy: 0.6557, Mean IoU: 0.0784, Frequency weighted IoU: 0.4878, Loss: 1.3245
# Epoch [6/80], Step [10/24], Loss: 1.0431
# Epoch [6/80], Step [20/24], Loss: 0.9742
# Pixel accuracy: 0.6909, Mean IoU: 0.0946, Frequency weighted IoU: 0.5277, Loss: 1.0814
# Epoch [7/80], Step [10/24], Loss: 1.0137
# Epoch [7/80], Step [20/24], Loss: 0.9577
# Pixel accuracy: 0.7379, Mean IoU: 0.1114, Frequency weighted IoU: 0.5847, Loss: 0.9308
# Epoch [8/80], Step [10/24], Loss: 0.9270
# Epoch [8/80], Step [20/24], Loss: 0.9469
# Pixel accuracy: 0.6253, Mean IoU: 0.0934, Frequency weighted IoU: 0.4548, Loss: 1.1846
# Epoch [9/80], Step [10/24], Loss: 0.9169
# Epoch [9/80], Step [20/24], Loss: 1.1516
# Pixel accuracy: 0.6823, Mean IoU: 0.1051, Frequency weighted IoU: 0.5178, Loss: 1.1849
# Epoch [10/80], Step [10/24], Loss: 1.0350
# Epoch [10/80], Step [20/24], Loss: 0.9871
# Pixel accuracy: 0.7327, Mean IoU: 0.1095, Frequency weighted IoU: 0.5781, Loss: 0.9887
# Epoch [11/80], Step [10/24], Loss: 0.9049
# Epoch [11/80], Step [20/24], Loss: 0.8362
# Pixel accuracy: 0.7329, Mean IoU: 0.1132, Frequency weighted IoU: 0.5784, Loss: 1.0346
# Epoch [12/80], Step [10/24], Loss: 0.8703
# Epoch [12/80], Step [20/24], Loss: 0.8160
# Pixel accuracy: 0.7578, Mean IoU: 0.1340, Frequency weighted IoU: 0.6100, Loss: 0.8808
# Epoch [13/80], Step [10/24], Loss: 0.8437
# Epoch [13/80], Step [20/24], Loss: 0.8054
# Pixel accuracy: 0.7641, Mean IoU: 0.1441, Frequency weighted IoU: 0.6183, Loss: 0.8489
# Epoch [14/80], Step [10/24], Loss: 0.7826
# Epoch [14/80], Step [20/24], Loss: 1.3498
# Pixel accuracy: 0.6673, Mean IoU: 0.0876, Frequency weighted IoU: 0.5007, Loss: 1.3099
# Epoch [15/80], Step [10/24], Loss: 1.2300
# Epoch [15/80], Step [20/24], Loss: 1.0905
# Pixel accuracy: 0.7009, Mean IoU: 0.1010, Frequency weighted IoU: 0.5395, Loss: 1.1319
# Epoch [16/80], Step [10/24], Loss: 1.0403
# Epoch [16/80], Step [20/24], Loss: 0.9289
# Pixel accuracy: 0.7491, Mean IoU: 0.1253, Frequency weighted IoU: 0.5988, Loss: 0.9193
# Epoch [17/80], Step [10/24], Loss: 0.8277
# Epoch [17/80], Step [20/24], Loss: 0.8041
# Pixel accuracy: 0.7774, Mean IoU: 0.1620, Frequency weighted IoU: 0.6359, Loss: 0.8113
# Epoch [18/80], Step [10/24], Loss: 0.7419
# Epoch [18/80], Step [20/24], Loss: 0.7551
# Pixel accuracy: 0.7774, Mean IoU: 0.1555, Frequency weighted IoU: 0.6359, Loss: 0.8049
# Epoch [19/80], Step [10/24], Loss: 0.7686
# Epoch [19/80], Step [20/24], Loss: 0.6889
# Pixel accuracy: 0.7966, Mean IoU: 0.1754, Frequency weighted IoU: 0.6619, Loss: 0.7434
# Epoch [20/80], Step [10/24], Loss: 0.6816
# Epoch [20/80], Step [20/24], Loss: 0.7399
# Pixel accuracy: 0.7733, Mean IoU: 0.1638, Frequency weighted IoU: 0.6305, Loss: 0.8359
# Epoch [21/80], Step [10/24], Loss: 0.7485
# Epoch [21/80], Step [20/24], Loss: 0.6721
# Pixel accuracy: 0.7729, Mean IoU: 0.1726, Frequency weighted IoU: 0.6299, Loss: 0.8152
# Epoch [22/80], Step [10/24], Loss: 0.8157
# Epoch [22/80], Step [20/24], Loss: 0.6827
# Pixel accuracy: 0.8017, Mean IoU: 0.1856, Frequency weighted IoU: 0.6690, Loss: 0.7426
